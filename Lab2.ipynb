# %% [markdown]
# # Task 1

# %%
class Classroom:
	
	var1 = None

	_var2 = None
	
	__var3 = None
	
	def __init__(self, var1, var2, var3):
		self.var1 = var1
		self._var2 = var2
		self.__var3 = var3
	
	def displayPublicMembers(self):

		print("Public Data Member: ", self.var1)
		
	def _displayProtectedMembers(self):

		print("Protected Data Member: ", self._var2)
	
	def __displayPrivateMembers(self):

		print("Private Data Member: ", self.__var3)

	def accessPrivateMembers(self):	
		
		self.__displayPrivateMembers()

class Sub(Classroom):

	def __init__(self, var1, var2, var3):
				Classroom.__init__(self, var1, var2, var3)
		
	def accessProtectedMembers(self):
				
				self._displayProtectedMembers()

obj = Sub("Geeks", 4, "Geeks !")

obj.displayPublicMembers()
obj.accessProtectedMembers()
obj.accessPrivateMembers()

print("Object is accessing protected member:", obj._var2)

obj1 = Classroom("Hello","Sir","Welcome")
# Out:
# Public Data Member:  Geeks
# Protected Data Member:  4
# Private Data Member:  Geeks !
# Object is accessing protected member: 4

# %% [markdown]
# # Task 2

# %%
names = ['Abbas','Zaidi','Faizan','Shayyan','Hamza']
for i,name in enumerate(names):
    print(f"My name is {name} and I came number  {i+1}")
# Out:
# My name is Abbas and I came number  1
# My name is Zaidi and I came number  2
# My name is Faizan and I came number  3
# My name is Shayyan and I came number  4
# My name is Hamza and I came number  5

# %% [markdown]
# # Task 3

# %%
def stringCounter(strings):
    count = 0
    for i in strings:
        if len(i)>=2 and i[0][0]== i[-1][-1]:
            count += 1
    return count

# %% [markdown]
# # Task 4

# %%
def SortStrings(strings):
    n= strings.sort()
    final=[]
    for i in n:
        if i[0][0] == 'x' or i[0][0] == 'X':
            final.append(i)
    for i in n:
        if i not in final:
            final.append(i)
    return final

# %% [markdown]
# # Task 5

# %%
def sortTuple(tuples,m):
    def last(n):
        return n[m]
    return sorted(tuples, key = last)

# %% [markdown]
# # Task 6

# %%
def RemoveAdjacent(lists):
    final=[]
    for i,num in enumerate(lists):
        if lists[i+1]!=num:
            final.append(num)
    return final

# %% [markdown]
# # Task 7

# %%
def mergeAndSort(l1,l2):
    l3=l1+l2
    return l3.sort(key = int)

# %% [markdown]
# # Task 8

# %%
import pandas as pd
df = pd.read_csv(r'E:\Uni\5thSem\ML\Lab\Lab2\drinks.csv')
print("Number of rows: ", df.shape[0])
df1=df.dropna()

def ColumnFinder(col_Name):
    try:
        return df['col_Name']
    except:
        print("Invalid column name")
# Out:
# Number of rows:  193

# %%
df1
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df1['continent'],df1['wine_servings'])
plt.show()

# %%
ax = plt.axes(projection ="3d")
ax.scatter3D(df1['beer_servings'], df1['wine_servings'], df1['spirit_servings'], color = "green")

# %%
plt.scatter(df1['beer_servings'], df1['wine_servings'], color = "green")

# %%
plt.bar(df1['continent'],df1['beer_servings'])
# Out:
# <BarContainer object of 170 artists>

# %%
plt.pie(df1['beer_servings'],labels=df1['continent'])
plt.plot()
# Out:
# []
